# %%
# clone pygcn from github and setup the environment (need to run only once)
# %%capture
# !git clone https://github.com/tkipf/pygcn
# %cd /content/pygcn
# !python setup.py install

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# train cora dataset at default parameter setting
# %%capture
# %cd /content/pygcn/pygcn
# !python train.py

# %%
# cora dataset default setting result
epochdata = pd.read_csv('epochdata.csv')

plt.plot(epochdata['epoch'], epochdata['loss_train'], label = "loss train")
plt.plot(epochdata['epoch'], epochdata['loss_val'], label = "loss validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.legend(loc='upper right')
plt.show()

plt.plot(epochdata['epoch'], epochdata['acc_train'], label = "accuracy train")
plt.plot(epochdata['epoch'], epochdata['acc_val'], label = "accuracy validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accurary',fontsize=16)
plt.legend(loc='upper left')
plt.show()

print('loss test: ', epochdata['loss_test'].iloc[0])
print('accurary test: ', epochdata['acc_test'].iloc[0])
# Out:
# loss test:  0.7701169848442078
# accurary test:  0.824

# %%
# %%capture
lr_testResult = pd.DataFrame()

for i in range(-5, 0):
    learning_rate = 10**i
    # !python train.py --lr={learning_rate}
    df = pd.read_csv('lr_result.csv')
    lr_testResult = pd.concat([lr_testResult, df], axis=0)

# %%
lr_testResult
# Out:
#         lr      loss  accuracy
# 0  0.00001  1.921023     0.150
# 0  0.00010  1.938429     0.081
# 0  0.00100  1.817699     0.309
# 0  0.01000  0.735690     0.826
# 0  0.10000  0.607534     0.816

# %%
# %%capture
do_testResult = pd.DataFrame()

for i in range(1, 10):
    dout = i / 10.0
    # !python train.py --dropout={dout}
    df = pd.read_csv('dropout_result.csv')
    do_testResult = pd.concat([do_testResult, df], axis=0)

# %%
do_testResult
# Out:
#    dropout      loss  accuracy
# 0      0.1  0.680762     0.828
# 0      0.2  0.702882     0.830
# 0      0.3  0.701869     0.842
# 0      0.4  0.710095     0.836
# 0      0.5  0.739779     0.821
# 0      0.6  0.753032     0.818
# 0      0.7  0.773069     0.831
# 0      0.8  0.891374     0.796
# 0      0.9  1.081118     0.767

# %%
# train cornell WebKB dataset at default parameter setting
# %%capture
# %cd /content/pygcn/pygcn
# !python train.py

# %%
# cornell WebKB dataset default setting result
epochdata = pd.read_csv('epochdata.csv')

plt.plot(epochdata['epoch'], epochdata['loss_train'], label = "loss train")
plt.plot(epochdata['epoch'], epochdata['loss_val'], label = "loss validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.legend(loc='upper right')
plt.show()

plt.plot(epochdata['epoch'], epochdata['acc_train'], label = "accuracy train")
plt.plot(epochdata['epoch'], epochdata['acc_val'], label = "accuracy validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accurary',fontsize=16)
plt.legend(loc='upper left')
plt.show()

print('loss test: ', epochdata['loss_test'].iloc[0])
print('accurary test: ', epochdata['acc_test'].iloc[0])
# Out:
# loss test:  0.7038812637329102
# accurary test:  0.829

# %%
# train texas WebKB dataset at default parameter setting
# %%capture
# %cd /content/pygcn/pygcn
# !python train.py

# %%
# texas WebKB dataset default setting result
epochdata = pd.read_csv('epochdata.csv')

plt.plot(epochdata['epoch'], epochdata['loss_train'], label = "loss train")
plt.plot(epochdata['epoch'], epochdata['loss_val'], label = "loss validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.legend(loc='upper right')
plt.show()

plt.plot(epochdata['epoch'], epochdata['acc_train'], label = "accuracy train")
plt.plot(epochdata['epoch'], epochdata['acc_val'], label = "accuracy validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accurary',fontsize=16)
plt.legend(loc='upper left')
plt.show()

print('loss test: ', epochdata['loss_test'].iloc[0])
print('accurary test: ', epochdata['acc_test'].iloc[0])
# Out:
# loss test:  0.735523521900177
# accurary test:  0.834

# %%
# train washington WebKB dataset at default parameter setting
# %%capture
# %cd /content/pygcn/pygcn
# !python train.py

# %%
# washington WebKB dataset default setting result
epochdata = pd.read_csv('epochdata.csv')

plt.plot(epochdata['epoch'], epochdata['loss_train'], label = "loss train")
plt.plot(epochdata['epoch'], epochdata['loss_val'], label = "loss validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.legend(loc='upper right')
plt.show()

plt.plot(epochdata['epoch'], epochdata['acc_train'], label = "accuracy train")
plt.plot(epochdata['epoch'], epochdata['acc_val'], label = "accuracy validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accurary',fontsize=16)
plt.legend(loc='upper left')
plt.show()

print('loss test: ', epochdata['loss_test'].iloc[0])
print('accurary test: ', epochdata['acc_test'].iloc[0])
# Out:
# loss test:  0.7001847624778748
# accurary test:  0.836

# %%
# train wisconsin WebKB dataset at default parameter setting
# %%capture
# %cd /content/pygcn/pygcn
# !python train.py

# %%
# wisconsin WebKB dataset default setting result
epochdata = pd.read_csv('epochdata.csv')

plt.plot(epochdata['epoch'], epochdata['loss_train'], label = "loss train")
plt.plot(epochdata['epoch'], epochdata['loss_val'], label = "loss validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.legend(loc='upper right')
plt.show()

plt.plot(epochdata['epoch'], epochdata['acc_train'], label = "accuracy train")
plt.plot(epochdata['epoch'], epochdata['acc_val'], label = "accuracy validation")
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accurary',fontsize=16)
plt.legend(loc='upper left')
plt.show()

print('loss test: ', epochdata['loss_test'].iloc[0])
print('accurary test: ', epochdata['acc_test'].iloc[0])
# Out:
# loss test:  0.7461475729942322
# accurary test:  0.823

# %%
# %%capture
import zipfile
import os
from google.colab import files
# compress the folder into a zip file
# !zip -r /content/CS598Final.zip /content/pygcn
